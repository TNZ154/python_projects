# %% [markdown]
# <a href="https://colab.research.google.com/github/TNZ154/python_projects/blob/main/IC_Python_activities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class student:
    grade=10
    print(f"Hi, I am a student of grade {grade}")
a=student()
# Out:
# Hi, I am a student of grade 10

# %%
class student:
  grade=10
  name="Turtle"
  def introduction(self):
    print("I'm a student")
  def detail(self):
    print(f"My name is {self.name}")
    print(f"I study in grade {self.grade}")
a=student()
a.introduction()
a.detail()
# Out:
# I'm a student
# My name is Turtle
# I study in grade 10
